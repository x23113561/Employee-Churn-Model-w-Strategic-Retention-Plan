# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load the data

# %%
# Load the data
data = pd.read_csv('C:/Users/thanm/OneDrive/Desktop/semester_2/elective/stores data-set.csv')
data.head(5)
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Store   45 non-null     int64
#  1   Type    45 non-null     object
#  2   Size    45 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ KB

# %% [markdown]
# ## Data Types

# %%
data_types = data.dtypes
data_types
# Out:
# Store     int64
# Type     object
# Size      int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# Encoding 'Type' using label encoding
label_encoder = LabelEncoder()
data['Type'] = label_encoder.fit_transform(data['Type'])

# %%
data.head(5)
# Out:
#    Store  Type    Size
# 0      1     0  151315
# 1      2     0  202307
# 2      3     1   37392
# 3      4     0  205863
# 4      5     1   34875

# %% [markdown]
# ## Summary

# %%
data = data.describe()
data
# Out:
#            Store       Type           Size
# count  45.000000  45.000000      45.000000
# mean   23.000000   0.644444  130287.600000
# std    13.133926   0.712089   63825.271991
# min     1.000000   0.000000   34875.000000
# 25%    12.000000   0.000000   70713.000000
# 50%    23.000000   1.000000  126512.000000
# 75%    34.000000   1.000000  202307.000000
# max    45.000000   2.000000  219622.000000

# %% [markdown]
# ## Checking for missing Values

# %%
# Check for missing values
initial_missing_count = data.isna().sum().sum()
initial_missing_count
# Out:
# 0

# %% [markdown]
# ## Removing duplicates

# %%
data = data.drop_duplicates()

# %% [markdown]
# ## Visualizations

# %%
sns.kdeplot(data['Size'])
plt.title('Density Plot of Store Sizes')
plt.xlabel('Size')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\thanm\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
type_counts = data['Type'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(type_counts, labels=type_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart of Store Types')
plt.show()
